# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
csv_file_path = 'outfinal/dbl.csv'

# Read the CSV file and create a DataFrame
dfdbl = pd.read_csv(csv_file_path)

h0_0=list(dfdbl['0.0'][8:13])
h1_0=list(dfdbl['0.0'][13:18])
h2_0=list(dfdbl['0.0'][18:23])
h3_0=list(dfdbl['0.0'][23:28])
h4_0=list(dfdbl['0.0'][28:33])

h0_5=list(dfdbl['0.05'][8:13])
h1_5=list(dfdbl['0.05'][13:18])
h2_5=list(dfdbl['0.05'][18:23])
h3_5=list(dfdbl['0.05'][23:28])
h4_5=list(dfdbl['0.05'][28:33])

h0_10=list(dfdbl['0.1'][8:13])
h1_10=list(dfdbl['0.1'][13:18])
h2_10=list(dfdbl['0.1'][18:23])
h3_10=list(dfdbl['0.1'][23:28])
h4_10=list(dfdbl['0.1'][28:33])

h0_20=list(dfdbl['0.2'][8:13])
h1_20=list(dfdbl['0.2'][13:18])
h2_20=list(dfdbl['0.2'][18:23])
h3_20=list(dfdbl['0.2'][23:28])
h4_20=list(dfdbl['0.2'][28:33])

h0_50=list(dfdbl['0.5'][8:13])
h1_50=list(dfdbl['0.5'][13:18])
h2_50=list(dfdbl['0.5'][18:23])
h3_50=list(dfdbl['0.5'][23:28])
h4_50=list(dfdbl['0.5'][28:33])

h0_100=list(dfdbl['1.0'][8:13])
h1_100=list(dfdbl['1.0'][13:18])
h2_100=list(dfdbl['1.0'][18:23])
h3_100=list(dfdbl['1.0'][23:28])
h4_100=list(dfdbl['1.0'][28:33])

import matplotlib.pyplot as plt

# Data
queries = ['h(0)', 'h(1)', 'h(2)', 'h(3)', 'h(4)']
buckets = ['[1]', '[2-4]', '[5-10]', '[11-20]', '[20-inf]']

perturbations = ['0%', '5%', '10%', '20%', '50%', '100%']

data = [
    {'h(0)': h0_0, 'h(1)': h1_0, 'h(2)': h2_0, 'h(3)': h3_0, 'h(4)': h4_0},
    {'h(0)': h0_5, 'h(1)': h1_5, 'h(2)': h2_5, 'h(3)': h3_5, 'h(4)': h4_5},
    {'h(0)': h0_10, 'h(1)': h1_10, 'h(2)': h2_10, 'h(3)': h3_10, 'h(4)': h4_10},
    {'h(0)': h0_20, 'h(1)': h1_20, 'h(2)': h2_20, 'h(3)': h3_20, 'h(4)': h4_20},
    {'h(0)': h0_50, 'h(1)': h1_50, 'h(2)': h2_50, 'h(3)': h3_50, 'h(4)': h4_50},
    {'h(0)': h0_100, 'h(1)': h1_100, 'h(2)': h2_100, 'h(3)': h3_100, 'h(4)': h4_100},
    # Add more data dictionaries if needed
]

# Plotting
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(10, 6))

colors = ['black', 'blue', 'orange', 'green', 'red']
markers = ['o', 's', '^', 'D', 'x']

for idx, data_dict in enumerate(data):
    row_idx, col_idx = divmod(idx, 3)
    ax = axes[row_idx, col_idx]

    for i, query in enumerate(queries):
        x_values = range(len(buckets))
        y_values = [data_dict[query][j] * 100 for j in range(len(buckets))]
        ax.plot(x_values, y_values, label=query, color=colors[i], marker=markers[i])

    ax.set_xticks(x_values)
    ax.set_xticklabels(buckets)
    ax.set_xlabel('Candidate Set Sizes')
    ax.set_ylabel('Percentage of Nodes')
    ax.legend()

    perturbation_percentage = perturbations[idx]
    ax.set_title(f'Perturbation: {perturbation_percentage}')
# Adjust layout to prevent clipping of titles
plt.suptitle('Distribution of Candidate Sets under Vertex Refinement Queries-dbl', fontsize=16)
plt.tight_layout()

# Show the plot
plt.show()

# %%
csv_file_path = 'outfinal/Amazon0302.csv'

# Read the CSV file and create a DataFrame
dfdbl = pd.read_csv(csv_file_path)


h0_0=list(dfdbl['0.0'][8:13])
h1_0=list(dfdbl['0.0'][13:18])
h2_0=list(dfdbl['0.0'][18:23])
h3_0=list(dfdbl['0.0'][23:28])
h4_0=list(dfdbl['0.0'][28:33])

h0_5=list(dfdbl['0.05'][8:13])
h1_5=list(dfdbl['0.05'][13:18])
h2_5=list(dfdbl['0.05'][18:23])
h3_5=list(dfdbl['0.05'][23:28])
h4_5=list(dfdbl['0.05'][28:33])

h0_10=list(dfdbl['0.1'][8:13])
h1_10=list(dfdbl['0.1'][13:18])
h2_10=list(dfdbl['0.1'][18:23])
h3_10=list(dfdbl['0.1'][23:28])
h4_10=list(dfdbl['0.1'][28:33])

h0_20=list(dfdbl['0.2'][8:13])
h1_20=list(dfdbl['0.2'][13:18])
h2_20=list(dfdbl['0.2'][18:23])
h3_20=list(dfdbl['0.2'][23:28])
h4_20=list(dfdbl['0.2'][28:33])

h0_50=list(dfdbl['0.5'][8:13])
h1_50=list(dfdbl['0.5'][13:18])
h2_50=list(dfdbl['0.5'][18:23])
h3_50=list(dfdbl['0.5'][23:28])
h4_50=list(dfdbl['0.5'][28:33])

h0_100=list(dfdbl['1.0'][8:13])
h1_100=list(dfdbl['1.0'][13:18])
h2_100=list(dfdbl['1.0'][18:23])
h3_100=list(dfdbl['1.0'][23:28])
h4_100=list(dfdbl['1.0'][28:33])

import matplotlib.pyplot as plt

# Data
queries = ['h(0)', 'h(1)', 'h(2)', 'h(3)', 'h(4)']
buckets = ['[1]', '[2-4]', '[5-10]', '[11-20]', '[20-inf]']

data = [
    {'h(0)': h0_0, 'h(1)': h1_0, 'h(2)': h2_0, 'h(3)': h3_0, 'h(4)': h4_0},
    {'h(0)': h0_5, 'h(1)': h1_5, 'h(2)': h2_5, 'h(3)': h3_5, 'h(4)': h4_5},
    {'h(0)': h0_10, 'h(1)': h1_10, 'h(2)': h2_10, 'h(3)': h3_10, 'h(4)': h4_10},
    {'h(0)': h0_20, 'h(1)': h1_20, 'h(2)': h2_20, 'h(3)': h3_20, 'h(4)': h4_20},
    {'h(0)': h0_50, 'h(1)': h1_50, 'h(2)': h2_50, 'h(3)': h3_50, 'h(4)': h4_50},
    {'h(0)': h0_100, 'h(1)': h1_100, 'h(2)': h2_100, 'h(3)': h3_100, 'h(4)': h4_100},
    # Add more data dictionaries if needed
]

# Plotting
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(10, 6))

colors = ['black', 'blue', 'orange', 'green', 'red']
markers = ['o', 's', '^', 'D', 'x']

for idx, data_dict in enumerate(data):
    row_idx, col_idx = divmod(idx, 3)
    ax = axes[row_idx, col_idx]

    for i, query in enumerate(queries):
        x_values = range(len(buckets))
        y_values = [data_dict[query][j] * 100 for j in range(len(buckets))]
        ax.plot(x_values, y_values, label=query, color=colors[i], marker=markers[i])

    ax.set_xticks(x_values)
    ax.set_xticklabels(buckets)
    ax.set_xlabel('Candidate Set Sizes')
    ax.set_ylabel('Percentage of Nodes')
    ax.legend()

    perturbation_percentage = perturbations[idx]
    ax.set_title(f'Perturbation: {perturbation_percentage}')

# Adjust layout to prevent clipping of titles
plt.suptitle('Distribution of Candidate Sets under Vertex Refinement Queries-Amazon', fontsize=16)
plt.tight_layout()

# Show the plot
plt.show()

# %%
csv_file_path = 'outfinal/facebook_combined.csv'

# Read the CSV file and create a DataFrame
dfdbl = pd.read_csv(csv_file_path)

h0_0=list(dfdbl['0'][8:13])
h1_0=list(dfdbl['0'][13:18])
h2_0=list(dfdbl['0'][18:23])
h3_0=list(dfdbl['0'][23:28])
h4_0=list(dfdbl['0'][28:33])

h0_5=list(dfdbl['0.05'][8:13])
h1_5=list(dfdbl['0.05'][13:18])
h2_5=list(dfdbl['0.05'][18:23])
h3_5=list(dfdbl['0.05'][23:28])
h4_5=list(dfdbl['0.05'][28:33])

h0_10=list(dfdbl['0.1'][8:13])
h1_10=list(dfdbl['0.1'][13:18])
h2_10=list(dfdbl['0.1'][18:23])
h3_10=list(dfdbl['0.1'][23:28])
h4_10=list(dfdbl['0.1'][28:33])

h0_20=list(dfdbl['0.2'][8:13])
h1_20=list(dfdbl['0.2'][13:18])
h2_20=list(dfdbl['0.2'][18:23])
h3_20=list(dfdbl['0.2'][23:28])
h4_20=list(dfdbl['0.2'][28:33])

h0_50=list(dfdbl['0.5'][8:13])
h1_50=list(dfdbl['0.5'][13:18])
h2_50=list(dfdbl['0.5'][18:23])
h3_50=list(dfdbl['0.5'][23:28])
h4_50=list(dfdbl['0.5'][28:33])

h0_100=list(dfdbl['1'][8:13])
h1_100=list(dfdbl['1'][13:18])
h2_100=list(dfdbl['1'][18:23])
h3_100=list(dfdbl['1'][23:28])
h4_100=list(dfdbl['1'][28:33])

import matplotlib.pyplot as plt

# Data
queries = ['h(0)', 'h(1)', 'h(2)', 'h(3)', 'h(4)']
buckets = ['[1]', '[2-4]', '[5-10]', '[11-20]', '[20-inf]']

data = [
    {'h(0)': h0_0, 'h(1)': h1_0, 'h(2)': h2_0, 'h(3)': h3_0, 'h(4)': h4_0},
    {'h(0)': h0_5, 'h(1)': h1_5, 'h(2)': h2_5, 'h(3)': h3_5, 'h(4)': h4_5},
    {'h(0)': h0_10, 'h(1)': h1_10, 'h(2)': h2_10, 'h(3)': h3_10, 'h(4)': h4_10},
    {'h(0)': h0_20, 'h(1)': h1_20, 'h(2)': h2_20, 'h(3)': h3_20, 'h(4)': h4_20},
    {'h(0)': h0_50, 'h(1)': h1_50, 'h(2)': h2_50, 'h(3)': h3_50, 'h(4)': h4_50},
    {'h(0)': h0_100, 'h(1)': h1_100, 'h(2)': h2_100, 'h(3)': h3_100, 'h(4)': h4_100},
    # Add more data dictionaries if needed
]

# Plotting
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(10, 6))

colors = ['black', 'blue', 'orange', 'green', 'red']
markers = ['o', 's', '^', 'D', 'x']

for idx, data_dict in enumerate(data):
    row_idx, col_idx = divmod(idx, 3)
    ax = axes[row_idx, col_idx]

    for i, query in enumerate(queries):
        x_values = range(len(buckets))
        y_values = [data_dict[query][j] * 100 for j in range(len(buckets))]
        ax.plot(x_values, y_values, label=query, color=colors[i], marker=markers[i])

    ax.set_xticks(x_values)
    ax.set_xticklabels(buckets)
    ax.set_xlabel('Candidate Set Sizes')
    ax.set_ylabel('Percentage of Nodes')
    ax.legend()

    perturbation_percentage = perturbations[idx]
    ax.set_title(f'Perturbation: {perturbation_percentage}')

# Adjust layout to prevent clipping of titles
plt.suptitle('Distribution of Candidate Sets under Vertex Refinement Queries-Facebook', fontsize=16)
plt.tight_layout()

# Show the plot
plt.show()

# %%
csv_file_path = 'outfinal/git.csv'

# Read the CSV file and create a DataFrame
dfdbl = pd.read_csv(csv_file_path)

h0_0=list(dfdbl['0.0'][8:13])
h1_0=list(dfdbl['0.0'][13:18])
h2_0=list(dfdbl['0.0'][18:23])
h3_0=list(dfdbl['0.0'][23:28])
h4_0=list(dfdbl['0.0'][28:33])

h0_5=list(dfdbl['0.05'][8:13])
h1_5=list(dfdbl['0.05'][13:18])
h2_5=list(dfdbl['0.05'][18:23])
h3_5=list(dfdbl['0.05'][23:28])
h4_5=list(dfdbl['0.05'][28:33])

h0_10=list(dfdbl['0.1'][8:13])
h1_10=list(dfdbl['0.1'][13:18])
h2_10=list(dfdbl['0.1'][18:23])
h3_10=list(dfdbl['0.1'][23:28])
h4_10=list(dfdbl['0.1'][28:33])

h0_20=list(dfdbl['0.2'][8:13])
h1_20=list(dfdbl['0.2'][13:18])
h2_20=list(dfdbl['0.2'][18:23])
h3_20=list(dfdbl['0.2'][23:28])
h4_20=list(dfdbl['0.2'][28:33])

h0_50=list(dfdbl['0.5'][8:13])
h1_50=list(dfdbl['0.5'][13:18])
h2_50=list(dfdbl['0.5'][18:23])
h3_50=list(dfdbl['0.5'][23:28])
h4_50=list(dfdbl['0.5'][28:33])

h0_100=list(dfdbl['1.0'][8:13])
h1_100=list(dfdbl['1.0'][13:18])
h2_100=list(dfdbl['1.0'][18:23])
h3_100=list(dfdbl['1.0'][23:28])
h4_100=list(dfdbl['1.0'][28:33])

import matplotlib.pyplot as plt

# Data
queries = ['h(0)', 'h(1)', 'h(2)', 'h(3)', 'h(4)']
buckets = ['[1]', '[2-4]', '[5-10]', '[11-20]', '[20-inf]']

data = [
    {'h(0)': h0_0, 'h(1)': h1_0, 'h(2)': h2_0, 'h(3)': h3_0, 'h(4)': h4_0},
    {'h(0)': h0_5, 'h(1)': h1_5, 'h(2)': h2_5, 'h(3)': h3_5, 'h(4)': h4_5},
    {'h(0)': h0_10, 'h(1)': h1_10, 'h(2)': h2_10, 'h(3)': h3_10, 'h(4)': h4_10},
    {'h(0)': h0_20, 'h(1)': h1_20, 'h(2)': h2_20, 'h(3)': h3_20, 'h(4)': h4_20},
    {'h(0)': h0_50, 'h(1)': h1_50, 'h(2)': h2_50, 'h(3)': h3_50, 'h(4)': h4_50},
    {'h(0)': h0_100, 'h(1)': h1_100, 'h(2)': h2_100, 'h(3)': h3_100, 'h(4)': h4_100},
    # Add more data dictionaries if needed
]

# Plotting
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(10, 6))

colors = ['black', 'blue', 'orange', 'green', 'red']
markers = ['o', 's', '^', 'D', 'x']

for idx, data_dict in enumerate(data):
    row_idx, col_idx = divmod(idx, 3)
    ax = axes[row_idx, col_idx]

    for i, query in enumerate(queries):
        x_values = range(len(buckets))
        y_values = [data_dict[query][j] * 100 for j in range(len(buckets))]
        ax.plot(x_values, y_values, label=query, color=colors[i], marker=markers[i])

    ax.set_xticks(x_values)
    ax.set_xticklabels(buckets)
    ax.set_xlabel('Candidate Set Sizes')
    ax.set_ylabel('Percentage of Nodes')
    ax.legend()

    perturbation_percentage = perturbations[idx]
    ax.set_title(f'Perturbation: {perturbation_percentage}')

# Adjust layout to prevent clipping of titles
plt.suptitle('Distribution of Candidate Sets under Vertex Refinement Queries-Git', fontsize=16)
plt.tight_layout()

# Show the plot
plt.show()

# %%
csv_file_path = 'outfinal/soc-Epinions1.csv'

# Read the CSV file and create a DataFrame
dfdbl = pd.read_csv(csv_file_path)

#pertirbation 0%
h0_0=list(dfdbl['0.0'][8:13])
h1_0=list(dfdbl['0.0'][13:18])
h2_0=list(dfdbl['0.0'][18:23])
h3_0=list(dfdbl['0.0'][23:28])
h4_0=list(dfdbl['0.0'][28:33])

#pertirbation 5%
h0_5=list(dfdbl['0.05'][8:13])
h1_5=list(dfdbl['0.05'][13:18])
h2_5=list(dfdbl['0.05'][18:23])
h3_5=list(dfdbl['0.05'][23:28])
h4_5=list(dfdbl['0.05'][28:33])

#pertirbation 10%
h0_10=list(dfdbl['0.1'][8:13])
h1_10=list(dfdbl['0.1'][13:18])
h2_10=list(dfdbl['0.1'][18:23])
h3_10=list(dfdbl['0.1'][23:28])
h4_10=list(dfdbl['0.1'][28:33])

#pertirbation 20%
h0_20=list(dfdbl['0.2'][8:13])
h1_20=list(dfdbl['0.2'][13:18])
h2_20=list(dfdbl['0.2'][18:23])
h3_20=list(dfdbl['0.2'][23:28])
h4_20=list(dfdbl['0.2'][28:33])

#pertirbation 50%
h0_50=list(dfdbl['0.5'][8:13])
h1_50=list(dfdbl['0.5'][13:18])
h2_50=list(dfdbl['0.5'][18:23])
h3_50=list(dfdbl['0.5'][23:28])
h4_50=list(dfdbl['0.5'][28:33])

#pertirbation 100%
h0_100=list(dfdbl['1.0'][8:13])
h1_100=list(dfdbl['1.0'][13:18])
h2_100=list(dfdbl['1.0'][18:23])
h3_100=list(dfdbl['1.0'][23:28])
h4_100=list(dfdbl['1.0'][28:33])

import matplotlib.pyplot as plt

# Data
queries = ['h(0)', 'h(1)', 'h(2)', 'h(3)', 'h(4)']
buckets = ['[1]', '[2-4]', '[5-10]', '[11-20]', '[20-inf]']

perturbations = ['0%', '5%', '10%', '20%', '50%', '100%']
data = [
    {'h(0)': h0_0, 'h(1)': h1_0, 'h(2)': h2_0, 'h(3)': h3_0, 'h(4)': h4_0},
    {'h(0)': h0_5, 'h(1)': h1_5, 'h(2)': h2_5, 'h(3)': h3_5, 'h(4)': h4_5},
    {'h(0)': h0_10, 'h(1)': h1_10, 'h(2)': h2_10, 'h(3)': h3_10, 'h(4)': h4_10},
    {'h(0)': h0_20, 'h(1)': h1_20, 'h(2)': h2_20, 'h(3)': h3_20, 'h(4)': h4_20},
    {'h(0)': h0_50, 'h(1)': h1_50, 'h(2)': h2_50, 'h(3)': h3_50, 'h(4)': h4_50},
    {'h(0)': h0_100, 'h(1)': h1_100, 'h(2)': h2_100, 'h(3)': h3_100, 'h(4)': h4_100},
    # Add more data dictionaries if needed
]

# Plotting
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(10, 6))

colors = ['black', 'blue', 'orange', 'green', 'red']
markers = ['o', 's', '^', 'D', 'x']

for idx, data_dict in enumerate(data):
    row_idx, col_idx = divmod(idx, 3)
    ax = axes[row_idx, col_idx]

    for i, query in enumerate(queries):
        x_values = range(len(buckets))
        y_values = [data_dict[query][j] * 100 for j in range(len(buckets))]
        ax.plot(x_values, y_values, label=query, color=colors[i], marker=markers[i])

    ax.set_xticks(x_values)
    ax.set_xticklabels(buckets)
    ax.set_xlabel('Candidate Set Sizes')
    ax.set_ylabel('Percentage of Nodes')
    ax.legend()

    
    perturbation_percentage = perturbations[idx]
    ax.set_title(f'Perturbation: {perturbation_percentage}')

    

# Adjust layout to prevent clipping of titles
plt.suptitle('Distribution of Candidate Sets under Vertex Refinement Queries-Epinions', fontsize=16)
plt.tight_layout()

# Show the plot
plt.show()
